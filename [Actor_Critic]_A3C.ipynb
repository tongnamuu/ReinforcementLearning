# %% [markdown]
# <a href="https://colab.research.google.com/github/tongnamuu/ReinforcementLearning/blob/master/%5BActor_Critic%5D_A3C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
import gym, argparse, numpy as np
from threading import Thread, Lock
from multiprocessing import cpu_count
tf.keras.backend.set_floatx('float64')

CUR_EPISODE = 0
actor_lr = 0.0005
critic_lr = 0.001
update_interval = 5
gamma = 0.99

class Actor:
    def __init__(self, state_dim, action_dim):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.model = self.create_model()
        self.opt = tf.keras.optimizers.Adam(actor_lr)
        self.entropy_beta = 0.01

    def create_model(self):
        return tf.keras.Sequential([
            Input((self.state_dim,)),
            Dense(32, activation='relu'),
            Dense(16, activation='relu'),
            Dense(self.action_dim, activation='softmax')
        ])

    def compute_loss(self, actions, logits, advantages):
        ce_loss = tf.keras.losses.SparseCategoricalCrossentropy(
            from_logits=True)
        entropy_loss = tf.keras.losses.CategoricalCrossentropy(
            from_logits=True)
        actions = tf.cast(actions, tf.int32)
        policy_loss = ce_loss(
            actions, logits, sample_weight=tf.stop_gradient(advantages))
        entropy = entropy_loss(logits, logits)
        return policy_loss - self.entropy_beta * entropy

    def train(self, states, actions, advantages):
        with tf.GradientTape() as tape:
            logits = self.model(states, training=True)
            loss = self.compute_loss(
                actions, logits, advantages)
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.opt.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss 


class Critic:
    def __init__(self, state_dim):
        self.state_dim = state_dim
        self.model = self.create_model()
        self.opt = tf.keras.optimizers.Adam(critic_lr)
    
    def create_model(self):
        return tf.keras.Sequential([
            Input((self.state_dim,)),
            Dense(32, activation='relu'),
            Dense(16, activation='relu'),
            Dense(16, activation='relu'),
            Dense(1, activation='linear')
        ])

    def compute_loss(self, v_pred, td_targets):
        mse = tf.keras.losses.MeanSquaredError()
        return mse(td_targets, v_pred)

    def train(self, states, td_targets):
        with tf.GradientTape() as tape:
            v_pred = self.model(states, training=True)
            assert v_pred.shape == td_targets.shape
            loss = self.compute_loss(v_pred, tf.stop_gradient(td_targets))
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.opt.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss
    

class Agent:
    def __init__(self, env_name):
        env = gym.make(env_name)
        self.env_name = env_name
        self.state_dim = env.observation_space.shape[0]
        self.action_dim = env.action_space.n

        self.global_actor = Actor(self.state_dim, self.action_dim)
        self.global_critic = Critic(self.state_dim)
        self.num_workers = cpu_count()

    def train(self, max_episodes=1000):
        workers = []

        for i in range(self.num_workers):
            env = gym.make(self.env_name)
            workers.append(WorkerAgent(
                env, self.global_actor, self.global_critic, max_episodes))

        for worker in workers:
            worker.start()

        for worker in workers:
            worker.join()


class WorkerAgent(Thread):
    def __init__(self, env, global_actor, global_critic, max_episodes):
        Thread.__init__(self)
        self.lock = Lock()
        self.env = env
        self.state_dim = self.env.observation_space.shape[0]
        self.action_dim = self.env.action_space.n

        self.max_episodes = max_episodes
        self.global_actor = global_actor
        self.global_critic = global_critic
        self.actor = Actor(self.state_dim, self.action_dim)
        self.critic = Critic(self.state_dim)

        self.actor.model.set_weights(self.global_actor.model.get_weights())
        self.critic.model.set_weights(self.global_critic.model.get_weights())

    def n_step_td_target(self, rewards, next_v_value, done):
        td_targets = np.zeros_like(rewards)
        cumulative = 0
        if not done:
            cumulative = next_v_value

        for k in reversed(range(0, len(rewards))):
            cumulative = gamma * cumulative + rewards[k]
            td_targets[k] = cumulative
        return td_targets

    def advatnage(self, td_targets, baselines):
        return td_targets - baselines

    def list_to_batch(self, list):
        batch = list[0]
        for elem in list[1:]:
            batch = np.append(batch, elem, axis=0)
        return batch

    def train(self):
        global CUR_EPISODE

        while self.max_episodes >= CUR_EPISODE:
            state_batch = []
            action_batch = []
            reward_batch = []
            episode_reward, done = 0, False

            state = self.env.reset()

            while not done:
                probs = self.actor.model.predict(
                    np.reshape(state, [1, self.state_dim]))
                action = np.random.choice(self.action_dim, p=probs[0])

                next_state, reward, done, _ = self.env.step(action)

                state = np.reshape(state, [1, self.state_dim])
                action = np.reshape(action, [1, 1])
                next_state = np.reshape(next_state, [1, self.state_dim])
                reward = np.reshape(reward, [1, 1])

                state_batch.append(state)
                action_batch.append(action)
                reward_batch.append(reward)

                if len(state_batch) >= update_interval or done:
                    states = self.list_to_batch(state_batch)
                    actions = self.list_to_batch(action_batch)
                    rewards = self.list_to_batch(reward_batch)

                    next_v_value = self.critic.model.predict(next_state)
                    td_targets = self.n_step_td_target(
                        rewards, next_v_value, done)
                    advantages = td_targets - self.critic.model.predict(states)
                    
                    with self.lock:
                        actor_loss = self.global_actor.train(
                            states, actions, advantages)
                        critic_loss = self.global_critic.train(
                            states, td_targets)

                        self.actor.model.set_weights(
                            self.global_actor.model.get_weights())
                        self.critic.model.set_weights(
                            self.global_critic.model.get_weights())

                    state_batch = []
                    action_batch = []
                    reward_batch = []
                    td_target_batch = []
                    advatnage_batch = []

                episode_reward += reward[0][0]
                state = next_state[0]

            print(f'EP{CUR_EPISODE} EpisodeReward = { episode_reward}')
            CUR_EPISODE += 1

    def run(self):
        self.train()


env_name = 'CartPole-v1'
agent = Agent(env_name)
agent.train()
# Out:
# EP0 EpisodeReward = 9.0
# EP1 EpisodeReward = 9.0
# EP2 EpisodeReward=39.0
# EP3 EpisodeReward = 22.0
# EP4 EpisodeReward = 9.0
# EP5 EpisodeReward = 11.0
# EP6 EpisodeReward = 10.0
# EP7 EpisodeReward=32.0
# EP8 EpisodeReward = 22.0
# EP9 EpisodeReward = 12.0
# EP10 EpisodeReward = 9.0
# EP11 EpisodeReward = 35.0
# EP12 EpisodeReward=33.0
# EP13 EpisodeReward = 10.0
# EP14 EpisodeReward = 9.0
# EP15 EpisodeReward=17.0
# EP16 EpisodeReward = 13.0
# EP17 EpisodeReward = 35.0
# EP18 EpisodeReward=13.0
# EP19 EpisodeReward = 8.0
# EP20 EpisodeReward = 13.0
# EP21 EpisodeReward = 13.0
# EP22 EpisodeReward=17.0
# EP23 EpisodeReward = 18.0
# EP24 EpisodeReward = 11.0
# EP25 EpisodeReward=24.0
# EP26 EpisodeReward = 20.0
# EP27 EpisodeReward = 35.0
# EP28 EpisodeReward = 10.0
# EP29 EpisodeReward = 9.0
# EP30 EpisodeReward=26.0
# EP31 EpisodeReward = 13.0
# EP32 EpisodeReward = 27.0
# EP33 EpisodeReward = 25.0
# EP34 EpisodeReward = 29.0
# EP35 EpisodeReward = 24.0
# EP36 EpisodeReward=67.0
# EP37 EpisodeReward = 34.0
# EP38 EpisodeReward = 29.0
# EP39 EpisodeReward = 12.0
# EP558 EpisodeReward=236.0
# EP559 EpisodeReward = 188.0
# EP560 EpisodeReward=207.0
# EP561 EpisodeReward = 248.0
# EP562 EpisodeReward=137.0
# EP563 EpisodeReward = 225.0
# EP564 EpisodeReward = 317.0
# EP565 EpisodeReward=183.0
# EP566 EpisodeReward=174.0
# EP567 EpisodeReward = 315.0
# EP568 EpisodeReward=97.0
# EP569 EpisodeReward = 453.0
# EP570 EpisodeReward=156.0
# EP571 EpisodeReward = 235.0
# EP572 EpisodeReward = 260.0
# EP573 EpisodeReward = 182.0
# EP574 EpisodeReward=358.0
# EP575 EpisodeReward = 247.0
# EP576 EpisodeReward = 293.0
# EP577 EpisodeReward=181.0
# EP578 EpisodeReward = 293.0
# EP579 EpisodeReward=283.0
# EP580 EpisodeReward = 355.0
# EP581 EpisodeReward = 342.0
# EP582 EpisodeReward = 223.0
# EP583 EpisodeReward=500.0
# EP584 EpisodeReward = 241.0
# EP585 EpisodeReward = 359.0
# EP586 EpisodeReward=170.0
# EP587 EpisodeReward = 246.0
# EP588 EpisodeReward = 222.0
# EP589 EpisodeReward=236.0
# EP590 EpisodeReward = 215.0
# EP591 EpisodeReward = 205.0
# EP592 EpisodeReward = 405.0
# EP593 EpisodeReward=460.0
# EP594 EpisodeReward = 291.0
# EP595 EpisodeReward=151.0
# EP596 EpisodeReward = 382.0
# EP597 EpisodeReward=151.0
# EP598 EpisodeReward=102.0
# EP599 EpisodeReward=100.0
# EP600 EpisodeReward = 276.0
# EP601 EpisodeReward=93.0
# EP602 EpisodeReward = 500.0
# EP603 EpisodeReward=108.0
# EP604 EpisodeReward = 186.0
# EP605 EpisodeReward = 217.0
# EP606 EpisodeReward=121.0
# EP607 EpisodeReward=78.0
# EP608 EpisodeReward = 169.0
# EP609 EpisodeReward = 176.0
# EP610 EpisodeReward=76.0
# EP611 EpisodeReward = 137.0
# EP612 EpisodeReward=164.0
# EP613 EpisodeReward = 196.0
# EP614 EpisodeReward=87.0
# EP615 EpisodeReward=71.0
# EP615 EpisodeReward = 205.0
# EP617 EpisodeReward=148.0
# EP618 EpisodeReward=113.0
# EP619 EpisodeReward = 267.0
# EP620 EpisodeReward = 460.0
# EP621 EpisodeReward=60.0
# EP622 EpisodeReward=255.0
# EP623 EpisodeReward=127.0
# EP624 EpisodeReward = 500.0
# EP625 EpisodeReward = 500.0
# EP626 EpisodeReward=185.0
# EP627 EpisodeReward = 164.0
# EP628 EpisodeReward = 224.0
# EP629 EpisodeReward=240.0
# EP630 EpisodeReward = 209.0
# EP631 EpisodeReward = 210.0
# EP632 EpisodeReward=199.0
# EP633 EpisodeReward = 237.0
# EP634 EpisodeReward = 322.0
# EP635 EpisodeReward=235.0
# EP636 EpisodeReward=169.0
# EP637 EpisodeReward=142.0
# EP638 EpisodeReward = 500.0
# EP639 EpisodeReward = 500.0
# EP640 EpisodeReward=165.0
# EP641 EpisodeReward=265.0
# EP642 EpisodeReward = 424.0
# EP643 EpisodeReward=193.0
# EP644 EpisodeReward = 500.0
